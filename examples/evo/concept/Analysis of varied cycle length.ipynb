# %%
-
# Out:
# Populating the interactive namespace from numpy and matplotlib
#    update   avg_age   max_age  avg_coop  avg_points  percentlying_defector  \
# 0       0   0.00000         0         1           0                      0
# 1      10  10.00000        10         1          10                      0
# 2      20  20.00000        20         1          20                      0
# 3      30   4.21795         5  0.997244           4                      0
# 4      40  14.21790        15  0.997244          14                      0
#
#    percentdonator   grid_usage   available_private_pts  replicant structure  \
# 0               1     0.100000                   75000          0  standard
# 1               1     0.011944                   74613          0  standard
# 2               1     0.011944                   74183          0  standard
# 3               1     0.021667                   73613          0  standard
# ...

# %%
sns.plt.suptitle("Average cooperation across varied cycle length (standard)")
ax = sns.tsplot( time="update", value=" avg_coop", unit="replicant", 
    condition="Spacing", ci=95, data=squished_base[squished_base['structure'] == 'standard'], color="hls")
#squished_base[squished_base['structure'] == 'mixed'].head()
