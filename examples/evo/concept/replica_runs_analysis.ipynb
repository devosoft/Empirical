# %%
import pandas as pd
from collections import defaultdict

loaded = defaultdict(list)
squished = []

file_labels = {
    "00": "defector (0%)",
    "100": "donator (100%)"
}

num_files = 10

print(file_labels)

for i in range(num_files):
    
    for key in file_labels:
        moo = pd.read_csv("./runs/{}percent-noevo-{}-quorum.csv".format(key, i), skipinitialspace=True)
        moo['replicant'] = "{0}".format(i)
        
        #moo.set_index(["update"])
        loaded[key].append(moo)

for key in file_labels:
    squash = pd.concat(loaded[key], axis=0)
    squash["config"] = file_labels[key]
    #print("Key {} and value{}".format(key, file_labels[key]))
    squished.append(squash)
    
super_squished = pd.concat(squished)
#super_squished = pd.concat([squished_coop, squished_balanced])
super_squished
# Out:
# {'100': 'donator (100%)', '00': 'defector (0%)'}
#      update    avg_age  max_age  avg_coop  avg_points replicant  \
# 0         0   0.000000        0         1     0.00000         0
# 1        10  10.000000       10         1    10.00000         0
# 2        20  20.000000       20         1    20.00000         0
# 3        30   3.871670       30         1     8.85694         0
# 4        40   2.878890       40         1    20.19690         0
# 5        50   2.112780       25         1    19.84080         0
# 6        60   2.195830       25         1    19.94420         0
# 7        70   2.277220       29         1    20.10220         0
# 8        80   2.179170       39         1    20.31640         0
# 9        90   2.216390       29         1    19.91250         0
# 10      100   2.199440       36         1    19.86610         0
# 11      110   2.221670       46         1    20.19110         0
# 12      120   2.307220       34         1    20.45720         0
# 13      130   2.256670       37         1    20.29690         0
# 14      140   2.289440       47         1    20.17440         0
# 15      150   2.265830       57         1    19.80830         0
# 16      160   2.200280       36         1    20.22220         0
# 17      170   2.214720       34         1    19.92440         0
# 18      180   2.251670       44         1    20.12860         0
# 19      190   2.333060       54         1    20.58610         0
# 20      200   2.230280       36         1    20.12110         0
# 21      210   2.229440       35         1    20.15280         0
# 22      220   2.281940       45         1    20.53920         0
# 23      230   2.193060       29         1    20.13830         0
# 24      240   2.291110       39         1    20.74500         0
# 25      250   2.222220       38         1    20.41250         0
# 26      260   2.272220       36         1    20.45310         0
# 27      270   2.285280       46         1    20.76060         0
# 28      280   2.280000       31         1    20.69080         0
# 29      290   2.268060       37         1    20.29310         0
# ..      ...        ...      ...       ...         ...       ...
# 470    4700   0.198056        1         0     0.00000         9
# 471    4710  10.198100       11         0    10.00000         9
# 472    4720  20.198100       21         0    20.00000         9
# 473    4730  30.198100       31         0    30.00000         9
# 474    4740  40.198100       41         0    40.00000         9
# 475    4750   0.203056        1         0     0.00000         9
# 476    4760  10.203100       11         0    10.00000         9
# 477    4770  20.203100       21         0    20.00000         9
# 478    4780  30.203100       31         0    30.00000         9
# 479    4790  40.203100       41         0    40.00000         9
# 480    4800   0.193333        1         0     0.00000         9
# 481    4810  10.193300       11         0    10.00000         9
# 482    4820  20.193300       21         0    20.00000         9
# 483    4830  30.193300       31         0    30.00000         9
# 484    4840  40.193300       41         0    40.00000         9
# 485    4850   0.194722        1         0     0.00000         9
# 486    4860  10.194700       11         0    10.00000         9
# 487    4870  20.194700       21         0    20.00000         9
# 488    4880  30.194700       31         0    30.00000         9
# 489    4890  40.194700       41         0    40.00000         9
# 490    4900   0.201944        1         0     0.00000         9
# 491    4910  10.201900       11         0    10.00000         9
# 492    4920  20.201900       21         0    20.00000         9
# 493    4930  30.201900       31         0    30.00000         9
# 494    4940  40.201900       41         0    40.00000         9
# 495    4950   0.205556        1         0     0.00000         9
# 496    4960  10.205600       11         0    10.00000         9
# 497    4970  20.205600       21         0    20.00000         9
# 498    4980  30.205600       31         0    30.00000         9
# 499    4990  40.205600       41         0    40.00000         9
#
#              config
# 0    donator (100%)
# 1    donator (100%)
# 2    donator (100%)
# 3    donator (100%)
# 4    donator (100%)
# 5    donator (100%)
# 6    donator (100%)
# 7    donator (100%)
# 8    donator (100%)
# 9    donator (100%)
# 10   donator (100%)
# 11   donator (100%)
# 12   donator (100%)
# 13   donator (100%)
# 14   donator (100%)
# 15   donator (100%)
# 16   donator (100%)
# 17   donator (100%)
# 18   donator (100%)
# 19   donator (100%)
# 20   donator (100%)
# 21   donator (100%)
# 22   donator (100%)
# 23   donator (100%)
# 24   donator (100%)
# 25   donator (100%)
# 26   donator (100%)
# 27   donator (100%)
# 28   donator (100%)
# 29   donator (100%)
# ..              ...
# 470   defector (0%)
# 471   defector (0%)
# 472   defector (0%)
# 473   defector (0%)
# 474   defector (0%)
# 475   defector (0%)
# 476   defector (0%)
# 477   defector (0%)
# 478   defector (0%)
# 479   defector (0%)
# 480   defector (0%)
# 481   defector (0%)
# 482   defector (0%)
# 483   defector (0%)
# 484   defector (0%)
# 485   defector (0%)
# 486   defector (0%)
# 487   defector (0%)
# 488   defector (0%)
# 489   defector (0%)
# 490   defector (0%)
# 491   defector (0%)
# 492   defector (0%)
# 493   defector (0%)
# 494   defector (0%)
# 495   defector (0%)
# 496   defector (0%)
# 497   defector (0%)
# 498   defector (0%)
# 499   defector (0%)
#
# [10000 rows x 7 columns]

# %% [markdown]
# #### Average Age Across Configurations
# --------------------------------

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (14, 8)

graphnum = 1

#sns.set(style="white", palette="muted", color_codes=True)
#sns.distplot(squish_grid.loc["{}0".format(prefix, graphnum)]["shannon_diversity"], bins=10)
#plt.plot(squish_grid.loc["{}0".format(prefix)]["shannon_diversity"])
ax = sns.tsplot(time="update", value="avg_age", unit="replicant", condition="config", data=super_squished)
#other_squished = super_squished.set_index(["update", "replicant", "config"])
#sns.swarmplot('update', 'avg_age', data=super_squished, hue='config')
#other_squished.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot(squish_mixed.loc["{}0".format(prefix)]["shannon_diversity"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-377014728097> in <module>()
# ----> 1 plt.plot(squish_mixed.loc["{}0".format(prefix)]["shannon_diversity"])
#
# NameError: name 'squish_mixed' is not defined

# %% [markdown]
# Shannon Diversity of 0th Cell
# -----------------------------

# %%
plt.plot(super_squished.loc["{0}1".format(prefix, graphnum)]["ShannonDiversity"])
plt.show()

# %% [markdown]
# Average & Max Fitness of 0th replicant
# --------------------------------------

# %%
plt.plot(super_squished.loc["{}0".format(prefix, graphnum)]["MaxFitness"])
plt.plot(super_squished.loc["{}0".format(prefix, graphnum)]["AvgFitness"])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1394                 if key not in ax:
# -> 1395                     error()
#    1396             except TypeError as e:
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in error()
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#
# KeyError: 'the label [yolo0] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-c2d7961f1e8d> in <module>()
# ----> 1 plt.plot(super_squished.loc["{}0".format(prefix, graphnum)]["MaxFitness"])
#       2 plt.plot(super_squished.loc["{}0".format(prefix, graphnum)]["AvgFitness"])
#       3
#       4 plt.show()
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1464
#    1465         # fall thru to straight lookup
# -> 1466         self._has_valid_type(key, axis)
#    1467         return self._get_label(key, axis=axis)
#    1468
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1401                 raise
#    1402             except:
# -> 1403                 error()
#    1404
#    1405         return True
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in error()
#    1388                                     "key")
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#    1392             try:
#
# KeyError: 'the label [yolo0] is not in the [index]'

# %%
plt.plot(squish.loc["{}1".format(prefix)]["ShannonDiversity"])

# %%
plt.plot(squish.loc["{}1".format(prefix)]["MaxFitness"])
plt.plot(squish.loc["{}1".format(prefix)]["AvgFitness"])
plt.show()
