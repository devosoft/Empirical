# %%
import pandas as pd
loaded_files = []
prefix = "catty"
num_files = 2
headers = ["{0}{1}".format(prefix, i) for i in range(num_files)]
for i in range(num_files):
    moo = pd.read_csv("./runs/{0}{1}".format(prefix, i))
    moo['replicant'] = "{0}{1}".format(prefix, i)
    moo.set_index(["replicant"])
    loaded_files.append(moo)

loaded_files[0]

squish = pd.concat(loaded_files, axis=0)
#squish
squish = squish.set_index(["replicant", "Update"])
squish.loc["catty0"]
#squish.loc["{}0".format(prefix)]
# Out:
#         ShannonDiversity  MaxFitness  AvgFitness
# Update
# 0                7.64386     214.469     203.388
# 1                7.49876     215.997     211.229
# 2                7.39594     216.972     214.505
# 3                7.55631     218.114     216.203
# 4                7.53203     219.693     217.472
# 5                7.53631     220.489     218.687
# 6                7.51631     221.774     219.754
# 7                7.55631     222.718     220.866
# 8                7.46498     223.596     221.936
# 9                7.56253     224.173     222.840
# 10               7.50826     225.060     223.650
# 11               7.51631     226.153     224.476
# 12               7.49826     227.200     225.353
# 13               7.48203     227.921     226.458
# 14               7.53631     229.368     227.237
# 15               7.42631     230.237     228.288
# 16               7.42203     231.335     229.607
# 17               7.42805     232.182     230.501
# 18               7.45253     233.903     231.344
# 19               7.48581     234.664     232.344
# 20               7.43182     235.553     233.752
# 21               7.46805     236.299     234.666
# 22               7.53008     237.217     235.491
# 23               7.40694     238.474     236.385
# 24               7.48826     239.075     237.233
# 25               7.53631     239.862     238.189
# 26               7.40071     241.074     239.200
# 27               7.52386     241.608     239.835
# 28               7.40448     242.515     240.865
# 29               7.47581     243.020     241.601
# ...                  ...         ...         ...
# 970              7.13889     274.002     273.306
# 971              7.18266     274.002     273.290
# 972              7.12332     274.002     273.293
# 973              7.21030     274.002     273.247
# 974              7.16266     274.002     273.321
# 975              7.03960     274.002     273.316
# 976              6.98902     274.002     273.234
# 977              7.13889     274.002     273.258
# 978              7.26856     274.002     273.301
# 979              7.17266     274.002     273.312
# 980              7.23030     274.002     273.203
# 981              7.29386     274.002     273.248
# 982              7.18166     274.002     273.300
# 983              7.36734     274.002     273.188
# 984              7.22030     274.002     273.247
# 985              7.15332     274.002     273.304
# 986              6.97195     274.002     273.293
# 987              6.84596     274.002     273.268
# 988              7.08366     274.002     273.300
# 989              7.08366     274.002     273.321
# 990              6.82977     274.002     273.357
# 991              6.74776     274.002     273.371
# 992              7.14266     274.002     273.257
# 993              6.98902     274.002     273.328
# 994              6.81596     274.002     273.327
# 995              6.96083     274.002     273.206
# 996              6.90945     274.002     273.313
# 997              6.96195     274.002     273.272
# 998              6.92945     274.002     273.283
# 999              7.00280     274.002     273.234
#
# [1000 rows x 3 columns]

# %% [markdown]
# Normal distribution of 0th graph
# --------------------------------

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

graphnum = 1

sns.set(style="white", palette="muted", color_codes=True)
sns.distplot(squish.loc["{}0".format(prefix, graphnum)]["ShannonDiversity"], bins=10)

# %% [markdown]
# Shannon Diversity of 0th Cell
# -----------------------------

# %%
plt.plot(squish.loc["{0}1".format(prefix, graphnum)]["ShannonDiversity"])
plt.show()

# %% [markdown]
# Average & Max Fitness of 0th replicant
# --------------------------------------

# %%
plt.plot(squish.loc["{}1".format(prefix, graphnum)]["MaxFitness"])
plt.plot(squish.loc["{}1".format(prefix, graphnum)]["AvgFitness"])

plt.show()

# %%
plt.plot(squish.loc["{}1".format(prefix)]["ShannonDiversity"])

# %%
plt.plot(squish.loc["{}1".format(prefix)]["MaxFitness"])
plt.plot(squish.loc["{}1".format(prefix)]["AvgFitness"])
plt.show()
