# %%
import pandas as pd
loaded_files = []
prefix = "catty"
num_files = 2
headers = ["{0}{1}".format(prefix, i) for i in range(num_files)]
for i in range(num_files):
    moo = pd.read_csv("./runs/{0}{1}".format(prefix, i))
    moo['replicant'] = "{0}{1}".format(prefix, i)
    moo.set_index(["replicant"])
    loaded_files.append(moo)

loaded_files[0]

squish = pd.concat(loaded_files, axis=0)
#squish
squish = squish.set_index(["replicant", "Update"])
squish.loc["catty0"]
#squish.loc["{}0".format(prefix)]
# Out:
#         ShannonDiversity  MaxFitness  AvgFitness
# Update
# 0                7.64386     205.504     194.892
# 1                7.54253     207.656     202.320
# 2                7.42826     208.823     205.914
# 3                7.46008     209.839     207.777
# 4                7.58631     211.336     209.114
# 5                7.57008     212.517     210.245
# 6                7.45071     213.422     211.457
# 7                7.45631     214.375     212.591
# 8                7.54631     215.327     213.704
# 9                7.55631     216.764     214.842
# 10               7.54008     218.121     215.819
# 11               7.49581     219.300     217.100
# 12               7.59386     219.837     218.116
# 13               7.52203     221.618     219.221
# 14               7.38253     222.630     220.305
# 15               7.50631     223.495     221.402
# 16               7.52631     223.931     222.402
# 17               7.35826     224.812     223.367
# 18               7.59008     226.358     224.122
# 19               7.53008     226.870     225.020
# 20               7.51008     227.649     226.101
# 21               7.49253     228.393     226.813
# 22               7.50826     229.098     227.596
# 23               7.57631     229.979     228.211
# 24               7.51008     230.948     229.123
# 25               7.50826     232.032     229.985
# 26               7.56631     232.814     230.891
# 27               7.47008     233.278     231.786
# 28               7.36971     234.510     232.672
# 29               7.54631     234.914     233.256
# ...                  ...         ...         ...
# 970              6.95083     263.605     262.903
# 971              7.10365     263.605     262.805
# 972              6.88782     263.605     262.942
# 973              7.02366     263.605     262.918
# 974              7.13889     263.605     262.962
# 975              6.91083     263.605     262.941
# 976              7.04366     263.605     262.941
# 977              7.01337     263.605     262.942
# 978              7.12332     263.605     262.836
# 979              7.10365     263.605     262.885
# 980              6.91328     263.605     262.941
# 981              7.05366     263.605     262.922
# 982              6.96195     263.605     262.911
# 983              7.05366     263.605     262.915
# 984              7.06365     263.605     262.930
# 985              6.98195     263.605     262.975
# 986              7.12266     263.605     262.916
# 987              6.90567     263.605     262.929
# 988              7.27642     263.605     262.925
# 989              7.00280     263.605     262.968
# 990              6.94195     263.605     262.921
# 991              6.86596     263.605     262.975
# 992              7.00280     263.605     262.887
# 993              7.27386     263.605     262.894
# 994              7.23856     263.605     262.938
# 995              6.95195     263.605     262.960
# 996              7.18166     263.605     262.832
# 997              6.96083     263.605     262.925
# 998              7.06366     263.605     262.847
# 999              6.88945     263.605     262.971
#
# [1000 rows x 3 columns]

# %% [markdown]
# Normal distribution of 0th graph
# --------------------------------

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

graphnum = 1

sns.set(style="white", palette="muted", color_codes=True)
sns.distplot(squish.loc["{}0".format(prefix, graphnum)]["ShannonDiversity"], bins=10)

# %% [markdown]
# Shannon Diversity of 0th Cell
# -----------------------------

# %%
plt.plot(squish.loc["{0}1".format(prefix, graphnum)]["ShannonDiversity"])
plt.show()

# %% [markdown]
# Average & Max Fitness of 0th replicant
# --------------------------------------

# %%
plt.plot(squish.loc["{}1".format(prefix, graphnum)]["MaxFitness"])
plt.plot(squish.loc["{}1".format(prefix, graphnum)]["AvgFitness"])

plt.show()

# %%
plt.plot(squish.loc["{}1".format(prefix)]["ShannonDiversity"])

# %%
plt.plot(squish.loc["{}1".format(prefix)]["MaxFitness"])
plt.plot(squish.loc["{}1".format(prefix)]["AvgFitness"])
plt.show()
