# %%
import pandas as pd
loaded_grid = []
loaded_mixed = []
loaded_pool = []
prefix = "newtest"
num_files = 1
headers = ["{0}{1}".format(prefix, i) for i in range(num_files)]
for i in range(num_files):
    moo = pd.read_csv("./runs/{0}{1}-grid.csv".format(prefix, i), skipinitialspace=True)
    moo['replicant'] = "{0}{1}".format(prefix, i)
    #moo.set_index(["update"])
    loaded_grid.append(moo)
    
    moo = pd.read_csv("./runs/{0}{1}-mixed.csv".format(prefix, i), skipinitialspace=True)
    moo['replicant'] = "{0}{1}".format(prefix, i)
    #moo.set_index(["update"])
    loaded_mixed.append(moo)
    
    moo = pd.read_csv("./runs/{0}{1}-pool.csv".format(prefix, i), skipinitialspace=True)
    moo['replicant'] = "{0}{1}".format(prefix, i)
    #moo.set_index(["update"])
    loaded_pool.append(moo)

squished_grid = pd.concat(loaded_grid, axis=0)
squished_grid['structure'] = "grid"
squished_mixed = pd.concat(loaded_mixed, axis=0)
squished_mixed['structure'] = "mixed"
squished_pool = pd.concat(loaded_pool, axis=0)
squished_pool['structure'] = "pool"

super_squished = pd.concat([squished_grid, squished_mixed, squished_pool])
super_squished.head()
# Out:
#    update  shannon_diversity  max_fitness  avg_fitness replicant structure
# 0       0            4.12151      212.090      206.336  newtest0      grid
# 1      10            4.83386      219.248      215.092  newtest0      grid
# 2      20            5.51032      226.021      222.800  newtest0      grid
# 3      30            5.40617      230.828      227.634  newtest0      grid
# 4      40            5.51492      235.991      233.127  newtest0      grid

# %% [markdown]
# Shannon Diversity of Different Structures
# --------------------------------

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (14, 8)

graphnum = 1

#sns.set(style="white", palette="muted", color_codes=True)
#sns.distplot(squish_grid.loc["{}0".format(prefix, graphnum)]["shannon_diversity"], bins=10)
#plt.plot(squish_grid.loc["{}0".format(prefix)]["shannon_diversity"])
ax = sns.tsplot(time="update", value="shannon_diversity", unit="replicant", condition="structure", data=super_squished)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot(squish_mixed.loc["{}0".format(prefix)]["shannon_diversity"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-377014728097> in <module>()
# ----> 1 plt.plot(squish_mixed.loc["{}0".format(prefix)]["shannon_diversity"])
#
# NameError: name 'squish_mixed' is not defined

# %% [markdown]
# Shannon Diversity of 0th Cell
# -----------------------------

# %%
plt.plot(super_squished.loc["{0}1".format(prefix, graphnum)]["ShannonDiversity"])
plt.show()

# %% [markdown]
# Average & Max Fitness of 0th replicant
# --------------------------------------

# %%
plt.plot(super_squished.loc["{}0-grid.csv".format(prefix, graphnum)]["MaxFitness"])
plt.plot(super_squished.loc["{}0".format(prefix, graphnum)]["AvgFitness"])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1394                 if key not in ax:
# -> 1395                     error()
#    1396             except TypeError as e:
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in error()
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#
# KeyError: 'the label [test-pool0] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-c2d7961f1e8d> in <module>()
# ----> 1 plt.plot(super_squished.loc["{}0".format(prefix, graphnum)]["MaxFitness"])
#       2 plt.plot(super_squished.loc["{}0".format(prefix, graphnum)]["AvgFitness"])
#       3
#       4 plt.show()
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1464
#    1465         # fall thru to straight lookup
# -> 1466         self._has_valid_type(key, axis)
#    1467         return self._get_label(key, axis=axis)
#    1468
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1401                 raise
#    1402             except:
# -> 1403                 error()
#    1404
#    1405         return True
#
# /home/sjorgensen/anaconda3/envs/pyaims/lib/python3.5/site-packages/pandas/core/indexing.py in error()
#    1388                                     "key")
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#    1392             try:
#
# KeyError: 'the label [test-pool0] is not in the [index]'

# %%
plt.plot(squish.loc["{}1".format(prefix)]["ShannonDiversity"])

# %%
plt.plot(squish.loc["{}1".format(prefix)]["MaxFitness"])
plt.plot(squish.loc["{}1".format(prefix)]["AvgFitness"])
plt.show()
